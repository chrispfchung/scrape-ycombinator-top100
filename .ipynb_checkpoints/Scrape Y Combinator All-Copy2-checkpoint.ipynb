# %% [markdown]
# ## Scraped Y Combinator's Top Companies and Added Data Into Excel

# %%
# https://www.youtube.com/watch?v=JfU1G1Ug6-k
    
import csv
import requests
import urllib.request
from bs4 import BeautifulSoup

url = 'https://www.ycombinator.com/topcompanies/'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)

# %%
mydivs = soup.findAll("div", class_="detailsBox")
mydivs
# Out:
# [<div class="detailsBox"> <span class="rank">#01</span> <a class="mobile-apply" href="https://stripe.com/jobs">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Stripe logo" class="img-responsive" src="/images/topcompanies/logo_stripe-de67cbc0.png"/></div> <div class="site"><b class="h4">Stripe</b><a href="https://stripe.com/"></a>stripe.com</div> </div> <p class="margin-bottom-15">Stripe builds economic infrastructure for the internet. Businesses of every size use the company’s software to accept online payments and run technically sophisticated financial operations in more than 100 countries. Stripe helps new companies get started and grow their revenues, and established businesses accelerate into new markets and launch new business models.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Patrick Collison and John Collison</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Financial Technology and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>2000</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S09</p> </div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#02</span> <a class="mobile-apply" href="https://careers.airbnb.com/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Airbnb logo" class="img-responsive" src="/images/topcompanies/logo_airbnb-40de0d45.png"/></div> <div class="site"><b class="h4">Airbnb</b><a href="https://airbnb.com/"></a>airbnb.com</div> </div> <p class="margin-bottom-15">Airbnb exists to create a world where anyone can belong anywhere, providing healthy travel that is local, authentic, diverse, inclusive and sustainable. They empower people around the world to unlock and monetize their spaces, passions and talents to become hospitality entrepreneurs. Airbnb provides access to 6+ million unique places to stay in 100,000+ cities and 40,000+ unique experiences run by hosts.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Brian Chesky, Joe Gebbia, Nathan Blecharczyk</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Consumer Goods and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>6000</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W09</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#03</span> <a class="mobile-apply" href="https://getcruise.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Cruise logo" class="img-responsive" src="/images/topcompanies/logo_cruise-2192843f.png"/></div> <div class="site"><b class="h4">Cruise</b><a href="https://getcruise.com/">getcruise.com</a></div> </div> <p class="margin-bottom-15">Cruise is building the world’s most advanced, all-electric, self-driving car technology to safely connect people with the places, things, and experiences they care about. Self-driving cars will help save lives, reimagine cities, redefine time in transit, and restore freedom of movement for individuals who live in dense urban settings. Acquired by GM in 2016.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Kyle Vogt and Daniel Kan</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Automotive</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>1500</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W14</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#04</span> <a class="mobile-apply" href="https://www.doordash.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="DoorDash logo" class="img-responsive" src="/images/topcompanies/logo_doordash-bd5467f0.png"/></div> <div class="site"><b class="h4">DoorDash</b><a href="https://www.doordash.com/">doordash.com</a></div> </div> <p class="margin-bottom-15">Starting with restaurants, DoorDash is building the last mile logistics network and commerce layer to help local businesses compete in the modern day era.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Tony Xu, Andy Fang, Stanley Tang</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Consumer Goods and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>1800</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S13</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#05</span> <a class="mobile-apply" href="https://www.coinbase.com/careers/positions?">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Coinbase logo" class="img-responsive" src="/images/topcompanies/logo_coinbase-55b4e26f.png"/></div> <div class="site"><b class="h4">Coinbase</b><a href="https://www.coinbase.com/">coinbase.com</a></div> </div> <p class="margin-bottom-15">Coinbase is the easiest and most trusted place to buy, sell, and manage cryptocurrencies, offering a suite of products for individual investors, active traders, businesses and institutions. Coinbase has built the world's leading compliant crypto company serving over 30 million accounts in over 100 countries.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Brian Armstrong and Fred Ehrsam</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Financial Technology and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>1000</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S12</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#06</span> <a class="mobile-apply" href="https://www.instacartcareers.com/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Instacart logo" class="img-responsive" src="/images/topcompanies/logo_instacart-b78a855c.png"/></div> <div class="site"><b class="h4">Instacart</b><a href="https://www.instacart.com/"></a>instacart.com</div> </div> <p class="margin-bottom-15">Instacart is the North American leader in grocery delivery and one of the fastest-growing companies in e-commerce. Instacart’s same-day delivery and pickup services bring fresh groceries and everyday essentials to busy people and families across the U.S. and Canada in as fast as an hour. They deliver from more than 20,000 stores across more than 5,500 cities in North America.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Apoorva Mehta, Max Mullen, Brandon Leonardo</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Consumer Goods and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>1100</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S12</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#07</span> <a class="mobile-apply" href="https://www.dropbox.com/jobs">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Dropbox logo" class="img-responsive" src="/images/topcompanies/logo_dropbox-24d8c6ee.png"/></div> <div class="site"><b class="h4">Dropbox</b><a href="https://www.dropbox.com/">dropbox.com</a></div> </div> <p class="margin-bottom-15">Dropbox is a leading global collaboration platform that's transforming the way people work together, from the smallest business to the largest enterprise. With more than 500 million registered users across 180 countries, their products are designed to establish a more enlightened way of working. They went public in 2018.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Drew Houston and Arash Ferdowsi </p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>2300</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S07</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#08</span> <a class="mobile-apply" href="https://www.ginkgobioworks.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Ginkgo Bioworks logo" class="img-responsive" src="/images/topcompanies/logo_ginkgo-fced0cd0.png"/></div> <div class="site"><b class="h4">Ginkgo Bioworks</b><a href="https://www.ginkgobioworks.com/">ginkgobioworks.com</a></div> </div> <p class="margin-bottom-15">Ginkgo Bioworks is a biotech company that programs cells for customers across multiple markets.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Reshma Shetty, Austin Che, Barry Canton, Tom Knight, Jason Kelly</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Biotech</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>270</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Boston, MA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S14</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#09</span> <a class="mobile-apply" href="https://gusto.com/about/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Gusto logo" class="img-responsive" src="/images/topcompanies/logo_gusto-f4fe630e.png"/></div> <div class="site"><b class="h4">Gusto</b><a href="https://gusto.com/"></a>gusto.com</div> </div> <p class="margin-bottom-15">Gusto is the people platform that provides small businesses with everything they need to take care of their teams, including payroll, health insurance benefits, employee self on-boarding, 401(K), time off requests, time tracking, and more. Gusto currently serves more than 100,000 small businesses across the U.S. and has a net promoter score of 75+.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Josh Reeves, Eddie Kim, Tomer London</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>1000</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA and Denver, CO</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W12</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#10</span> <a class="mobile-apply" href="https://www.flexport.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Flexport logo" class="img-responsive" src="/images/topcompanies/logo_flexport-049b1b9a.png"/></div> <div class="site"><b class="h4">Flexport</b><a href="https://www.flexport.com/">flexport.com</a></div> </div> <p class="margin-bottom-15">Freight forwarding is the circulatory system for global trade. It still largely runs on paper. Flexport is changing this with a strategic operating model for modern businesses that powers more transparent, more agile, more efficient, and more profitable global supply chains.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Ryan Petersen</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>1700</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W14</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#11</span> <a class="mobile-apply" href="https://jobs.lever.co/rappi">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Rappi logo" class="img-responsive" src="/images/topcompanies/logo_rappi-751cf7df.png"/></div> <div class="site"><b class="h4">Rappi</b><a href="https://rappi.com/">rappi.com</a></div> </div> <p class="margin-bottom-15">Rappi is building on-demand delivery and financial services for Latin America.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Simon Borrero, Felipe Villamarin, Sebastian Mejia</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Consumer Goods and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>3900</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Bogota, Colombia</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W16</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#12</span> <a class="mobile-apply" href="https://careers.brex.com/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Brex logo" class="img-responsive" src="/images/topcompanies/logo_brex-a0b94792.png"/></div> <div class="site"><b class="h4">Brex</b><a href="https://brex.com/">brex.com</a></div> </div> <p class="margin-bottom-15">Brex does corporate credit cards.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Henrique Dubugras and Pedro Franceschi</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Financial Technology and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>300</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>F18</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W17</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#13</span> <a class="mobile-apply" href="https://www.redditinc.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Reddit logo" class="img-responsive" src="/images/topcompanies/logo_reddit-51d99fea.png"/></div> <div class="site"><b class="h4">Reddit</b><a href="https://www.reddit.com/"></a>reddit.com</div> </div> <p class="margin-bottom-15">Reddit is a network of communities where individuals can find experiences built around their interests, hobbies and passions. Redditors submit, vote and comment on content, stories and discussions about the topics they care about the most. With over 330 million global users monthly, Reddit is home to the most open and authentic conversations on the Internet.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Steve Huffman and Alexis Ohanian</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Consumer Media</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>500</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S05</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#14</span> <a class="mobile-apply" href="https://about.gitlab.com/jobs/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="GitLab logo" class="img-responsive" src="/images/topcompanies/logo_gitlab-b70264d1.png"/></div> <div class="site"><b class="h4">GitLab</b><a href="https://about.gitlab.com/">about.gitlab.com</a></div> </div> <p class="margin-bottom-15">GitLab is a complete DevOps platform, delivered as a single application. Built on open source, GitLab leverages the community contributions of thousands of developers and millions of users to continuously deliver new DevOps innovations. More than 100,000 organizations from startups to global enterprise organizations trust GitLab to deliver great software at new speeds.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Sid Sijbrandij and Dmitriy Zaporozhets</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>842</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Remote</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>S17</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W15</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#15</span> <a class="mobile-apply" href="https://www.pagerduty.com/careers/#pd-positions">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="PagerDuty, Inc. logo" class="img-responsive" src="/images/topcompanies/logo_pagerduty-fb7eea57.png"/></div> <div class="site"><b class="h4">PagerDuty, Inc.</b><a href="https://www.pagerduty.com/">pagerduty.com</a></div> </div> <p class="margin-bottom-15">PagerDuty acts as the central nervous system for the digital enterprise. They empower DevOps, IT operations, support, security, and business leaders to turn any signal into insight and real-time action across any operational use case. Their products help organizations improve operations, accelerate innovation, increase revenue, mitigate security risk, and deliver great customer experience.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Alex Solomon, Baskar Puvanathasan, Andrew Miklas</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>524</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S10</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#16</span> <a class="mobile-apply" href="https://checkr.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Checkr, Inc logo" class="img-responsive" src="/images/topcompanies/logo_checkr-9266a017.png"/></div> <div class="site"><b class="h4">Checkr, Inc</b><a href="https://checkr.com/">checkr.com</a></div> </div> <p class="margin-bottom-15">Checkr is disrupting the background check industry and creating solutions that will power the future of work. Checkr’s product has shifted the on-demand economy and has continued to scale into serving enterprise companies across various industries.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Daniel Yanisse and Jonathan Perichon</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>400</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA and Denver, CO</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>S17</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S14</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#17</span> <a class="mobile-apply" href="https://segment.com/jobs/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Segment logo" class="img-responsive" src="/images/topcompanies/logo_segment-e8a28010.png"/></div> <div class="site"><b class="h4">Segment</b><a href="https://segment.com/">segment.com</a></div> </div> <p class="margin-bottom-15">Segment is the world's leading provider of Customer Data Infrastructure (CDI). Thousands of companies across 71 countries, from high-growth startups to the world’s largest enterprises, use Segment to collect, clean and connect their first-party data to the applications they need to run their businesses.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Peter Reinhardt, Calvin French-Owen, Ilya Volodarsky, Ian Storm Taylor</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>440</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>S17</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S11</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#18</span> <a class="mobile-apply" href="https://www.docker.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Docker logo" class="img-responsive" src="/images/topcompanies/logo_docker-9cab7096.png"/></div> <div class="site"><b class="h4">Docker</b><a href="https://www.docker.com/">docker.com</a></div> </div> <p class="margin-bottom-15">Docker provides a platform for building, sharing and running modern applications. With Docker, organizations have the freedom to build and manage any application from existing to greenfield and securely run them anywhere, from hybrid cloud to the edge — without technology or infrastructure lock-in.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Solomon Hykes</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>400</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S10</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#19</span> <a class="mobile-apply" href="https://scale.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Scale logo" class="img-responsive" src="/images/topcompanies/logo_scale-657d4109.png"/></div> <div class="site"><b class="h4">Scale</b><a href="https://scale.com/">scale.com</a></div> </div> <p class="margin-bottom-15">Scale builds infrastructure to accelerate the development of AI. Their first product is a platform for training data and validation data to empower faster development.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Alexandr Wang</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>90</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>W19</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S16</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#20</span> <a class="mobile-apply" href="https://www.faire.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Faire logo" class="img-responsive" src="/images/topcompanies/logo_faire-028d285a.png"/></div> <div class="site"><b class="h4">Faire</b><a href="https://www.faire.com/">faire.com</a></div> </div> <p class="margin-bottom-15">Faire is a curated wholesale marketplace connecting more than 40,000 local retailers with thousands of hand-selected emerging and established brands. Faire enables independent retailers to grow with the advantages of big box terms, and empowers makers to build and run thriving businesses that create stronger local communities.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Max Rhodes, Daniele Perito, Marcelo Cortes</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>240</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA and Kitchener, Canada</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>F18</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W17</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#21</span> <a class="mobile-apply" href="https://www.twitch.tv/jobs/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Twitch logo" class="img-responsive" src="/images/topcompanies/logo_twitch-0dc07297.png"/></div> <div class="site"><b class="h4">Twitch</b><a href="https://www.twitch.tv/">twitch.tv</a></div> </div> <p class="margin-bottom-15">Twitch is a global community that comes together each day to create multiplayer entertainment: unique, live, unpredictable experiences created by the shared interactions of millions. Acquired by Amazon in 2014.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Emmett Shear, Justin Kan, Michael Seibel, Kyle Vogt</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Consumer Media</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>1500</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W07</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#22</span> <a class="mobile-apply" href="https://www.plangrid.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="PlanGrid logo" class="img-responsive" src="/images/topcompanies/logo_plangrid-3977788c.png"/></div> <div class="site"><b class="h4">PlanGrid</b><a href="https://www.plangrid.com/">plangrid.com</a></div> </div> <p class="margin-bottom-15">PlanGrid builds construction software. Acquired by Autodesk in 2018.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Ralph Gootee, Antoine Hersen, Kenny Stone, Ryan Sutton-Gee, Tracy Young</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Construction</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>450</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W12</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#23</span> <a class="mobile-apply" href="https://mixpanel.com/jobs/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Mixpanel logo" class="img-responsive" src="/images/topcompanies/logo_mixpanel-126a5644.png"/></div> <div class="site"><b class="h4">Mixpanel</b><a href="https://mixpanel.com/">mixpanel.com</a></div> </div> <p class="margin-bottom-15">With Mixpanel, companies can analyze how and why their users engage, convert, and retain in real-time across web, mobile, and smart devices. And then use that data to improve their business and products—all in one place.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Suhail Doshi and Tim Trefren</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>475</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S09</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#24</span> <a class="mobile-apply" href="https://amplitude.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Amplitude logo" class="img-responsive" src="/images/topcompanies/logo_amplitude-91a37861.png"/></div> <div class="site"><b class="h4">Amplitude</b><a href="https://amplitude.com/">amplitude.com</a></div> </div> <p class="margin-bottom-15">Amplitude is the world's #1 product intelligence platform. We empower teams to use customer data to build great product experiences for growth.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Spenser Skates, Curtis Liu, Jeffrey Wang</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>300</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W12</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#25</span> <a class="mobile-apply" href="https://www.optimizely.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Optimizely logo" class="img-responsive" src="/images/topcompanies/logo_optimizely-8c88dee3.png"/></div> <div class="site"><b class="h4">Optimizely</b><a href="https://www.optimizely.com/">optimizely.com</a></div> </div> <p class="margin-bottom-15">Optimizely offers a complete set of digital experience optimization technologies, including AI-powered personalization and experimentation, which encompasses A/B testing, multivariate testing, and server-side testing. They take out the guesswork to enable brands to deliver relevant experiences driven by data.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Pete Koomen and Dan Siroker</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>506</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W10</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#26</span> <a class="mobile-apply" href="https://boomsupersonic.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Boom Supersonic logo" class="img-responsive" src="/images/topcompanies/logo_boom-7482235f.png"/></div> <div class="site"><b class="h4">Boom Supersonic</b><a href="https://boomsupersonic.com/">boomsupersonic.com</a></div> </div> <p class="margin-bottom-15">Boom Supersonic is building Overture, history’s fastest commercial airliner. Boom’s vision is to bring families, businesses, and cultures closer together through supersonic travel and make the world dramatically more accessible. The company is backed by world-class investors and has 30 aircraft on pre-order from Japan Airlines and Virgin Group.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Blake Scholl</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Aerospace</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>150</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Denver, CO</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>S18</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W16</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#27</span> <a class="mobile-apply" href="https://boards.greenhouse.io/grow99">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Grin logo" class="img-responsive" src="/images/topcompanies/logo_grin-aec3ea13.png"/></div> <div class="site"><b class="h4">Grin</b><a href="http://www.ongrin.com">ongrin.com</a></div> </div> <p class="margin-bottom-15">Grin is a micromobility and payments platform for Latam.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Sergio Romo and Jonathan Lewy</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Consumer Goods and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>2000</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Mexico City, Mexico</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S18</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#28</span> <a class="mobile-apply" href="https://meesho.com/tech">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Meesho logo" class="img-responsive" src="/images/topcompanies/logo_meesho-d219ed2e.png"/></div> <div class="site"><b class="h4">Meesho</b><a href="https://meesho.com">meesho.com</a></div> </div> <p class="margin-bottom-15">Meesho is India's largest social commerce platform. Meesho gives entrepreneurs a platform with social sharing integrations with WhatsApp, Facebook and Instagram, that let them easily share products with friends, family, and their larger social network. Meesho also provides them with the right supply, logistics and payment capabilities to successfully run their business.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Vidit Aatrey and Sanjeev Barnwal</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Financial Technology and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>1122</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Bangalore, India</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S16</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#29</span> <a class="mobile-apply" href="https://www.algolia.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Algolia logo" class="img-responsive" src="/images/topcompanies/logo_algolia-24f7d341.png"/></div> <div class="site"><b class="h4">Algolia</b><a href="https://www.algolia.com/">algolia.com</a></div> </div> <p class="margin-bottom-15 margin-top-5">Algolia is the search-as-a-service platform that enables companies of all sizes to deliver fast, relevant and scalable search and discovery experiences for consumers across web, mobile, and voice. Algolia allows developers and product teams to build conversational, consumer-grade search to increase online engagement, conversion and revenue.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Julien Lemoine and Nicolas Dessaigne</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>338</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>S18</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W14</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#30</span> <a class="mobile-apply" href="https://www.goat.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="GOAT logo" class="img-responsive" src="/images/topcompanies/logo_goat-8edde3b3.png"/></div> <div class="site"><b class="h4">GOAT</b><a href="https://www.goat.com/">goat.com</a></div> </div> <p class="margin-bottom-15">GOAT Group is the world’s largest marketplace for authentic sneakers. The company offers the greatest selection of sneakers available through retail stores, websites and mobile apps under the GOAT and Flight Club brands.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Eddy Lu and Daishin Sugano</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Consumer Goods and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>650</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Los Angeles, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W11</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#31</span> <a class="mobile-apply" href="https://zapier.com/jobs/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Zapier logo" class="img-responsive" src="/images/topcompanies/logo_zapier-7566e5e7.png"/></div> <div class="site"><b class="h4">Zapier</b><a href="https://zapier.com/">zapier.com</a></div> </div> <p class="margin-bottom-15">Zapier helps you be more productive and grow your business through automation.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Wade Foster, Bryan Helmig, Mike Knoop</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>250</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Remote</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>S18</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S12</p></div> </div> </div> </div> </div> </div>,
# ...
#  <div class="detailsBox"> <span class="rank">#92</span> <a class="mobile-apply" href="https://www.guesty.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Guesty logo" class="img-responsive" src="/images/topcompanies/logo_guesty-4dbc2b17.png"/></div> <div class="site"><b class="h4">Guesty</b><a href="https://www.guesty.com/">guesty.com</a></div> </div> <p class="margin-bottom-15">Guesty is property management software. Their solution simplifies the complex operational needs that property managers face on a daily basis – from guest communication to task assignment to payment processing.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Amiad Soto and Koby Soto</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>270</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Tel Aviv, Israel</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W14</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#93</span> <a class="mobile-apply" href="https://axoni.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Axoni logo" class="img-responsive" src="/images/topcompanies/logo_axoni-d75c0c13.png"/></div> <div class="site"><b class="h4">Axoni</b><a href="https://axoni.com/">axoni.com</a></div> </div> <p class="margin-bottom-15">Axoni’s distributed ledger technology provides secure, multi-party data infrastructure with unparalleled performance.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Jeff Schvey and Greg Schvey</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Financial Technology and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>80</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>New York City, NY</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W14</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#94</span> <a class="mobile-apply" href="https://lob.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Lob logo" class="img-responsive" src="/images/topcompanies/logo_lob-f3ea0f86.png"/></div> <div class="site"><b class="h4">Lob</b><a href="https://lob.com/">lob.com</a></div> </div> <p class="margin-bottom-15">Founded in 2013 with a vision of automating the offline world, Lob is an API company that transforms the largely manual process of printing and mailing into an automated service that integrates directly with CRM, marketing automation, and data tools.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Leore Avidar and Harry Zhang</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>B2B Software and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>92</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>S17</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S13</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#95</span> <a class="mobile-apply" href="https://notablelabs.com/careers/">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Notable logo" class="img-responsive" src="/images/topcompanies/logo_notable-6eb97091.png"/></div> <div class="site"><b class="h4">Notable</b><a href="https://notablelabs.com/">notablelabs.com</a></div> </div> <p class="margin-bottom-15">Notable is transforming the way cancer is treated. Notable’s approach combines AI with an automated lab to determine which drugs or combination of drugs will be most effective for specific types of cancers.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Matt De Silva, Pete Quinzio, Diane Heiser PhD</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Biotech</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>35</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Foster City, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W15</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#96</span> <a class="mobile-apply" href="http://atomwise.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Atomwise Inc logo" class="img-responsive" src="/images/topcompanies/logo_atomwise-d7dcf7ce.png"/></div> <div class="site"><b class="h4">Atomwise Inc</b><a href="http://atomwise.com/">atomwise.com</a></div> </div> <p class="margin-bottom-15">Atomwise discovers new medicines using computational design. Its discoveries help partners deliver better medicines faster.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Abraham Heifets and Izhar Wallach</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Biotech</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>40</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W15</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#97</span> <a class="mobile-apply" href="https://careers.flutterwave.com">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Flutterwave Inc logo" class="img-responsive" src="/images/topcompanies/logo_flutterwave-ed43cd67.png"/></div> <div class="site"><b class="h4">Flutterwave Inc</b><a href="https://flutterwave.com">flutterwave.com</a></div> </div> <p class="margin-bottom-15">Flutterwave is building digital payment infrastructure for Africa. Their API enables merchants to process credit cards and local alternative payments across Africa.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Olugbenga GB Agboola and Iyinoluwa Aboyeji</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Financial Technology and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>120</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Lagos, Nigeria and San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S16</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#98</span> <a class="mobile-apply" href="https://www.panoramaed.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Panorama Education logo" class="img-responsive" src="/images/topcompanies/logo_panoramaeducation-b5ae32ad.png"/></div> <div class="site"><b class="h4">Panorama Education</b><a href="https://www.panoramaed.com/">panoramaed.com</a></div> </div> <p class="margin-bottom-15">Panorama helps educators use data to support each student’s needs, and helps leaders build great schools. The platform helps build students' social-emotional skills and get more students prepared for college, their careers, and life.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Aaron Feuer and Xan Tanner</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Education</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>140</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Boston, MA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S13</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#99</span> <a class="mobile-apply" href="https://careers.blackrock.com">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="FutureAdvisor logo" class="img-responsive" src="/images/topcompanies/logo_futureadvisor-49ff9b48.png"/></div> <div class="site"><b class="h4">FutureAdvisor</b><a href="https://www.futureadvisor.com/">futureadvisor.com</a></div> </div> <p class="margin-bottom-15">FutureAdvisor helps people reach their long-term financial goals by managing their savings and investments. Acquired by Blackrock in 2015.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Jon Xu and Bo Lu</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Financial Technology and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>85</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S10</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#100</span> <a class="mobile-apply" href="https://www.sfox.com/jobs.html">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="SFOX logo" class="img-responsive" src="/images/topcompanies/logo_sfox-6b589e3b.png"/></div> <div class="site"><b class="h4">SFOX</b><a href="https://www.sfox.com/">sfox.com</a></div> </div> <p class="margin-bottom-15">SFOX is a better way to trade digital currencies, offering the best price and deepest liquidity with a single point of access to global cryptocurrency markets.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Akbar Thobhani and George Melika</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Financial Technology and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>35</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>Remote</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S14</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#101</span> <a class="mobile-apply" href="https://lambdaschool.com/careers">APPLY</a> <div class="intro"> <div class="sideImage"><img alt="Lambda School logo" class="img-responsive" src="/images/topcompanies/logo_lambdaschool-29c82e5e.png"/></div> <div class="site"><b class="h4">Lambda School</b><a href="https://lambdaschool.com">lambdaschool.com</a></div> </div> <p class="margin-bottom-15">Lambda School is a revolutionary school that trains people to be software engineers and data scientists at no upfront cost. Students won't pay a cent until they land a job.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Austen Allred and Ben Nelson</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Education</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>140</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>W19</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>S17</p></div> </div> </div> </div> </div> </div>,
#  <div class="detailsBox"> <span class="rank">#102</span> <div class="intro"> <div class="sideImage"><img alt="ZeroDown logo" class="img-responsive" src="/images/topcompanies/logo_zerodown-8720a120.png"/></div> <div class="site"><b class="h4">ZeroDown</b><a href="https://www.zerodown.com/">zerodown.com</a></div> </div> <p class="margin-bottom-15">ZeroDown is creating a new pathway to homeownership by enabling you to own a home without needing a downpayment.</p> <p class="no-margin m-founders">FOUNDERS</p> <p class="margin-bottom-15">Abhijeet Dwivedi, Laks Srini, Hari Viswanathan</p> <div class="row scorColumn"> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Sector</b><p>Financial Technology and Services</p></div> </div> </div> <div class="row m-jobs-col"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Jobs Created</b><p>15</p></div> </div> </div> </div> <div class="col-sm-6 col-xs-6"> <div class="row"> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">HQ</b><p>San Francisco, CA</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">YCG Batch</b><p>—</p></div> </div> <div class="col-sm-12 col-xs-12"> <div><b class="text-uppercase">Batch</b><p>W19</p></div> </div> </div> </div> </div> </div>]

# %% [markdown]
# ### All Companies

# %%
company = []
for divs in range(len(mydivs)):
    company.append(mydivs[divs].find('b', class_='h4').text)
# Out:
# Stripe
# Airbnb
# Cruise
# DoorDash
# Coinbase
# Instacart
# Dropbox
# Ginkgo Bioworks
# Gusto
# Flexport
# Rappi
# Brex
# Reddit
# GitLab
# PagerDuty, Inc.
# Checkr, Inc
# Segment
# Docker
# Scale
# Faire
# Twitch
# PlanGrid
# Mixpanel
# Amplitude
# Optimizely
# Boom Supersonic
# Grin
# Meesho
# Algolia
# GOAT
# Zapier
# MessageBird
# Standard Cognition
# Memebox
# Embark
# Helion Energy
# EquipmentShare
# SendBird
# Rescale
# GoCardless
# Rigetti Computing
# Razorpay
# North
# Relativity Space
# Podium
# Benchling
# Ironclad
# Newfront
# InfluxData
# Webflow
# People.ai
# Weebly
# Xendit
# Matterport Inc
# EasyPost
# Sift
# The Athletic
# Mattermost
# WePay
# Vidyard
# Weave
# Nurx
# Proxy, Inc.
# Heap
# Presto
# Payfazz
# memsql
# Fivetran
# Rippling
# Clever
# Heroku
# Fivestars
# CoreOS
# ClearTax
# Quero Education
# Ridecell
# HelloSign (acquired by Dropbox)
# GrubMarket Inc
# Lattice
# Unbabel
# Athelas Inc.
# Oh My Green
# Lever
# Atrium
# Zeus
# Front
# Le Tote
# ShipBob
# Snapdocs
# GitPrime
# Scribd
# Guesty
# Axoni
# Lob
# Notable
# Atomwise Inc
# Flutterwave Inc
# Panorama Education
# FutureAdvisor
# SFOX
# Lambda School
# ZeroDown

# %% [markdown]
# ### Company Rank

# %%
# one company's rank

rank = mydivs[0].findAll(text=True)[1]
rank = mydivs[0].find('span').text
rank
# Out:
# '#01'

# %%
# all company ranks
ranks = []
for divs in range(len(mydivs)):
    ranks.append(mydivs[divs].span.text)
# ranks

# %% [markdown]
# ### Founders

# %%
#One set of founders for a company
mydivs[0].findAll('p', class_='margin-bottom-15')[1].text
# Out:
# 'Patrick Collison and John Collison'

# %%
# All founders
founders = []
for i in range(len(mydivs)):
    founders.append(mydivs[i].findAll('p', class_='margin-bottom-15')[1].text)
# founders

# %% [markdown]
# ### Sector

# %%
# One sector for a company
mydivs[0].findAll('p')[3].text
# Out:
# 'Financial Technology and Services'

# %%
# all sectors
sectors = []
for i in range(len(mydivs)):
    sectors.append(mydivs[i].findAll('p')[3].text)
# sectors

# %% [markdown]
# ### Jobs Created

# %%
# all sectors
jobs_created = []
for i in range(len(mydivs)):
    jobs_created.append(mydivs[i].findAll('p')[4].text)
# jobs_created

# %% [markdown]
# ### Company Description

# %%
# one company description
mydivs[0].findAll('p')[0].text
# Out:
# 'Stripe builds economic infrastructure for the internet. Businesses of every size use the company’s software to accept online payments and run technically sophisticated financial operations in more than 100 countries. Stripe helps new companies get started and grow their revenues, and established businesses accelerate into new markets and launch new business models.'

# %%
# all company descriptions
description = []
for divs in range(len(mydivs)):
    description.append(mydivs[divs].findAll('p')[0].text)
# description

# %% [markdown]
# ### Batch

# %%
# all batches
batches = []
for i in range(len(mydivs)):
    batches.append(mydivs[i].findAll('p')[7].text)
# batches

# %% [markdown]
# ## Adding into Excel

# %%
results = ['rank','company', 'founders','sector','jobs_created','company_description','batch']

# %%
for result in results:
    print(result+'.encode("utf-8")')
# Out:
# rank.encode("utf-8")
# company.encode("utf-8")
# founders.encode("utf-8")
# sector.encode("utf-8")
# jobs_created.encode("utf-8")
# company_description.encode("utf-8")
# batch.encode("utf-8")

# %%
#     writer.writerow(ranks.encode, company.encode("utf-8"), founders.encode("utf-8"), sector.encode("utf-8"),
#                    jobs_created.encode("utf-8"), company_description.encode("utf-8"), batch.encode("utf-8"))

# %%
## Part 2
#Put data into CSV and then open in Excel
# possibly add headers
# newFN = ['Rank', 'Company', 'Founders', 'Sector', 'Batch', 'Number of Jobs Created', 'Company Description']
# writer.writerow(newFN)
file = open('ycombo.csv', 'w')
writer = csv.writer(file)

#write writer row
writer.writerow(['ranks','company', 'founders','sector','jobs_created','company_description','batch'])

# f = open('dataoutput.csv', 'w', newline= '')
# writer = csv.writer(f, delimiter=',', dialect='excel')
results = [ranks, company, founders, sectors, batches, jobs_created, description]

writer.writerow(results)
# Out:
# 30712

# %%
import pandas as pd
pd.read_csv('ycombo.csv')
# Out:
#                                                ranks  \
# 0  ['#01', '#02', '#03', '#04', '#05', '#06', '#0...
#
#                                              company  \
# 0  ['Stripe', 'Airbnb', 'Cruise', 'DoorDash', 'Co...
#
#                                             founders  \
# 0  ['Patrick Collison and John Collison', 'Brian ...
#
#                                               sector  \
# 0  ['Financial Technology and Services', 'Consume...
#
#                                         jobs_created  \
# 0  ['S09', 'W09', 'W14', 'S13', 'S12', 'S12', 'S0...
#
#                                  company_description  \
# 0  ['2000', '6000', '1500', '1800', '1000', '1100...
#
#                                                batch
# 0  ['Stripe builds economic infrastructure for th...
